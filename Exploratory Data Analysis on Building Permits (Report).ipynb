# %% [markdown]
# # Report for Exploratory Data Analysis on Building Permits

# %% [markdown]
# The deductions below were made, after performing an Exploratory Data Analysis on the
# Building Permits dataset, by data visualization:

# %% [markdown]
# 1. The Permit Type 8 has the highest count of permits filed.

# %% [markdown]
# ## Count of Permits by Permit Type
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. The Financial District/South Beach Neighborhood has the highest building permits filed.

# %% [markdown]
# ## Count of Permits by Neighborhoods - Analysis Boundaries
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. The Permit Type 8 has the highest cost estimate.

# %% [markdown]
# ## Estimated Cost by Permit Type
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 4. Building that have no plans to add more units have highest cost estimates.

# %% [markdown]
# ## Estimated Cost of Proposed Units by Permit Type
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. The highest cost estimates are for buildings with plans to add more stories.

# %% [markdown]
# ## Estimated Cost of Number of Proposed Stories by Permit Type
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. About 90,000 of the permits filed have their current status as complete, while around 80,000 were just issued.

# %% [markdown]
# ## Count of Permit by Current Status
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. The count of fire related permits filed is about 10% of the whole dataset count. This means about 1 in every 10 building which filed for this permit may have had fire related hazards.

# %% [markdown]
# ## Count of Fire Only Permits filed
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. Pacific Heights is the Neigborhood with the highest cost estimate.

# %% [markdown]
# ## Estimated Cost by Neighborhoods - Analysis Boundaries
# ![image.png](attachment:image.png)

# %% [markdown]
# 9. There are very minimal correlations between the categories in the dataset, and so may not be able to influence each other evidently.

# %% [markdown]
# ## Heatmap to visualize if there are correlations
# ![image.png](attachment:image.png)
